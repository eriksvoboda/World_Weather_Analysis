# %%
# Import the dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combos

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the lats and lngs to a list

coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities

cities = []

# ID the nearest city for each latitude and longitude combos

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
        
# Print thecity count to confirm sufficient count
len(cities)
# Out:
# 757

# %%
# import the requests library

import requests

# import the API key

from config import weather_api_key

# %%
# Starting URL for Weather map api call

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and thedatetime module from the datetime library
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval    ")
print("----------------------------")

# Create counters

record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# ----------------------------

# %%
# loop through all the cities in our list
# add enumerate() method to reference the index and the city in the list
for i, city in enumerate(cities):

    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | ciudad guayana
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | qaanaaq
# Processing Record 5 of Set 1 | kapaa
# Processing Record 6 of Set 1 | cape town
# Processing Record 7 of Set 1 | serenje
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | provideniya
# Processing Record 10 of Set 1 | bambous virieux
# Processing Record 11 of Set 1 | praya
# Processing Record 12 of Set 1 | new norfolk
# Processing Record 13 of Set 1 | naze
# Processing Record 14 of Set 1 | shahapur
# Processing Record 15 of Set 1 | butaritari
# Processing Record 16 of Set 1 | tuktoyaktuk
# Processing Record 17 of Set 1 | paamiut
# Processing Record 18 of Set 1 | tromso
# Processing Record 19 of Set 1 | palmer
# Processing Record 20 of Set 1 | saskylakh
# Processing Record 21 of Set 1 | pevek
# Processing Record 22 of Set 1 | calderitas
# Processing Record 23 of Set 1 | souillac
# Processing Record 24 of Set 1 | rawson
# Processing Record 25 of Set 1 | fougamou
# Processing Record 26 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | rio verde de mato grosso
# Processing Record 29 of Set 1 | ukiah
# Processing Record 30 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 1 | nautla
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | nikolskoye
# Processing Record 34 of Set 1 | sao mateus do sul
# Processing Record 35 of Set 1 | mehamn
# Processing Record 36 of Set 1 | asau
# Processing Record 37 of Set 1 | hofn
# Processing Record 38 of Set 1 | aguimes
# Processing Record 39 of Set 1 | upernavik
# Processing Record 40 of Set 1 | salalah
# Processing Record 41 of Set 1 | ancud
# Processing Record 42 of Set 1 | marrakesh
# Processing Record 43 of Set 1 | yellowknife
# Processing Record 44 of Set 1 | almaty
# Processing Record 45 of Set 1 | tiksi
# Processing Record 46 of Set 1 | dubbo
# Processing Record 47 of Set 1 | nakamura
# Processing Record 48 of Set 1 | constitucion
# Processing Record 49 of Set 1 | atuona
# Processing Record 50 of Set 1 | lalpur
# Processing Record 1 of Set 2 | itanhaem
# Processing Record 2 of Set 2 | kaseda
# Processing Record 3 of Set 2 | wittenberge
# Processing Record 4 of Set 2 | puerto ayora
# Processing Record 5 of Set 2 | maniitsoq
# Processing Record 6 of Set 2 | torbay
# Processing Record 7 of Set 2 | hobart
# Processing Record 8 of Set 2 | luderitz
# Processing Record 9 of Set 2 | raudeberg
# Processing Record 10 of Set 2 | rajbiraj
# Processing Record 11 of Set 2 | mar del plata
# Processing Record 12 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 2 | normandin
# Processing Record 14 of Set 2 | bethel
# Processing Record 15 of Set 2 | jiangyou
# Processing Record 16 of Set 2 | karratha
# Processing Record 17 of Set 2 | vaini
# Processing Record 18 of Set 2 | wanaka
# Processing Record 19 of Set 2 | livny
# Processing Record 20 of Set 2 | umm jarr
# City not found. Skipping...
# Processing Record 21 of Set 2 | caucaia
# Processing Record 22 of Set 2 | mayo
# Processing Record 23 of Set 2 | bluff
# Processing Record 24 of Set 2 | aberdeen
# Processing Record 25 of Set 2 | tianpeng
# Processing Record 26 of Set 2 | mataura
# Processing Record 27 of Set 2 | arraial do cabo
# Processing Record 28 of Set 2 | sakakah
# Processing Record 29 of Set 2 | esperance
# Processing Record 30 of Set 2 | bengkulu
# Processing Record 31 of Set 2 | ribeira grande
# Processing Record 32 of Set 2 | hengshan
# Processing Record 33 of Set 2 | pangnirtung
# Processing Record 34 of Set 2 | chokurdakh
# Processing Record 35 of Set 2 | north platte
# Processing Record 36 of Set 2 | kyren
# Processing Record 37 of Set 2 | sidvokodvo
# Processing Record 38 of Set 2 | ushuaia
# Processing Record 39 of Set 2 | aleksandrovskoye
# Processing Record 40 of Set 2 | victoria
# Processing Record 41 of Set 2 | kollo
# Processing Record 42 of Set 2 | portland
# Processing Record 43 of Set 2 | port alfred
# Processing Record 44 of Set 2 | copiapo
# Processing Record 45 of Set 2 | lukaya
# Processing Record 46 of Set 2 | vuktyl
# Processing Record 47 of Set 2 | albany
# Processing Record 48 of Set 2 | roald
# Processing Record 49 of Set 2 | san cristobal
# Processing Record 50 of Set 2 | thompson
# Processing Record 1 of Set 3 | cam ranh
# Processing Record 2 of Set 3 | jamestown
# Processing Record 3 of Set 3 | saint-augustin
# Processing Record 4 of Set 3 | gat
# Processing Record 5 of Set 3 | castro
# Processing Record 6 of Set 3 | aviles
# Processing Record 7 of Set 3 | nanortalik
# Processing Record 8 of Set 3 | neon petritsion
# Processing Record 9 of Set 3 | saldanha
# Processing Record 10 of Set 3 | mount gambier
# Processing Record 11 of Set 3 | avera
# Processing Record 12 of Set 3 | touros
# Processing Record 13 of Set 3 | khatanga
# Processing Record 14 of Set 3 | corrales
# Processing Record 15 of Set 3 | tuatapere
# Processing Record 16 of Set 3 | puerto parra
# Processing Record 17 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 3 | bad kissingen
# Processing Record 19 of Set 3 | senmonorom
# City not found. Skipping...
# Processing Record 20 of Set 3 | bambanglipuro
# Processing Record 21 of Set 3 | georgetown
# Processing Record 22 of Set 3 | maldonado
# Processing Record 23 of Set 3 | viedma
# Processing Record 24 of Set 3 | iqaluit
# Processing Record 25 of Set 3 | emerald
# Processing Record 26 of Set 3 | panama city
# Processing Record 27 of Set 3 | matucana
# Processing Record 28 of Set 3 | tasiilaq
# Processing Record 29 of Set 3 | lorengau
# Processing Record 30 of Set 3 | yanam
# Processing Record 31 of Set 3 | hambantota
# Processing Record 32 of Set 3 | husavik
# Processing Record 33 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 3 | pochutla
# Processing Record 35 of Set 3 | alice
# Processing Record 36 of Set 3 | kavaratti
# Processing Record 37 of Set 3 | tigil
# Processing Record 38 of Set 3 | tabriz
# Processing Record 39 of Set 3 | ponta do sol
# Processing Record 40 of Set 3 | biak
# Processing Record 41 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 3 | sassandra
# Processing Record 43 of Set 3 | carnarvon
# Processing Record 44 of Set 3 | linares
# Processing Record 45 of Set 3 | morondava
# Processing Record 46 of Set 3 | san patricio
# Processing Record 47 of Set 3 | avarua
# Processing Record 48 of Set 3 | necochea
# Processing Record 49 of Set 3 | barrow
# Processing Record 50 of Set 3 | staunton
# Processing Record 1 of Set 4 | burleson
# Processing Record 2 of Set 4 | guerrero negro
# Processing Record 3 of Set 4 | faanui
# Processing Record 4 of Set 4 | howard springs
# Processing Record 5 of Set 4 | college
# Processing Record 6 of Set 4 | saint-denis
# Processing Record 7 of Set 4 | hilo
# Processing Record 8 of Set 4 | tomatlan
# Processing Record 9 of Set 4 | marsh harbour
# Processing Record 10 of Set 4 | fremont
# Processing Record 11 of Set 4 | kabare
# Processing Record 12 of Set 4 | amga
# Processing Record 13 of Set 4 | inhapi
# Processing Record 14 of Set 4 | saint-philippe
# Processing Record 15 of Set 4 | hobyo
# Processing Record 16 of Set 4 | vagur
# Processing Record 17 of Set 4 | meridian
# Processing Record 18 of Set 4 | vostok
# Processing Record 19 of Set 4 | chapais
# Processing Record 20 of Set 4 | naftah
# City not found. Skipping...
# Processing Record 21 of Set 4 | karaman
# Processing Record 22 of Set 4 | tres arroyos
# Processing Record 23 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 24 of Set 4 | karpathos
# Processing Record 25 of Set 4 | samarai
# Processing Record 26 of Set 4 | northam
# Processing Record 27 of Set 4 | kenai
# Processing Record 28 of Set 4 | sunrise manor
# Processing Record 29 of Set 4 | tondano
# Processing Record 30 of Set 4 | toora-khem
# Processing Record 31 of Set 4 | lang son
# Processing Record 32 of Set 4 | yenagoa
# Processing Record 33 of Set 4 | kalmunai
# Processing Record 34 of Set 4 | severo-kurilsk
# Processing Record 35 of Set 4 | kungurtug
# Processing Record 36 of Set 4 | kloulklubed
# Processing Record 37 of Set 4 | codrington
# Processing Record 38 of Set 4 | anloga
# Processing Record 39 of Set 4 | palana
# Processing Record 40 of Set 4 | bontang
# Processing Record 41 of Set 4 | kerur
# Processing Record 42 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 4 | arecibo
# Processing Record 44 of Set 4 | cidreira
# Processing Record 45 of Set 4 | tilichiki
# Processing Record 46 of Set 4 | juegang
# Processing Record 47 of Set 4 | bubaque
# Processing Record 48 of Set 4 | male
# Processing Record 49 of Set 4 | puerto carreno
# Processing Record 50 of Set 4 | vengerovo
# Processing Record 1 of Set 5 | ashtabula
# Processing Record 2 of Set 5 | aliganj
# Processing Record 3 of Set 5 | atbasar
# Processing Record 4 of Set 5 | miles city
# Processing Record 5 of Set 5 | norman wells
# Processing Record 6 of Set 5 | asfi
# Processing Record 7 of Set 5 | bara
# Processing Record 8 of Set 5 | nome
# Processing Record 9 of Set 5 | manama
# Processing Record 10 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 5 | port lincoln
# Processing Record 12 of Set 5 | kodiak
# Processing Record 13 of Set 5 | talnakh
# Processing Record 14 of Set 5 | baculin
# Processing Record 15 of Set 5 | novo aripuana
# Processing Record 16 of Set 5 | manzhouli
# Processing Record 17 of Set 5 | klaksvik
# Processing Record 18 of Set 5 | kahului
# Processing Record 19 of Set 5 | lata
# Processing Record 20 of Set 5 | laramie
# Processing Record 21 of Set 5 | arman
# Processing Record 22 of Set 5 | alofi
# Processing Record 23 of Set 5 | hithadhoo
# Processing Record 24 of Set 5 | henties bay
# Processing Record 25 of Set 5 | tautira
# Processing Record 26 of Set 5 | ternate
# Processing Record 27 of Set 5 | rust
# Processing Record 28 of Set 5 | port elizabeth
# Processing Record 29 of Set 5 | adrar
# Processing Record 30 of Set 5 | skibbereen
# Processing Record 31 of Set 5 | dingle
# Processing Record 32 of Set 5 | sorgun
# Processing Record 33 of Set 5 | kaduqli
# Processing Record 34 of Set 5 | lavrentiya
# Processing Record 35 of Set 5 | abensberg
# Processing Record 36 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 5 | hami
# Processing Record 39 of Set 5 | cotonou
# Processing Record 40 of Set 5 | malusteni
# Processing Record 41 of Set 5 | geraldton
# Processing Record 42 of Set 5 | marystown
# Processing Record 43 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 44 of Set 5 | burgeo
# Processing Record 45 of Set 5 | kununurra
# Processing Record 46 of Set 5 | aklavik
# Processing Record 47 of Set 5 | buala
# Processing Record 48 of Set 5 | shingu
# Processing Record 49 of Set 5 | chumikan
# Processing Record 50 of Set 5 | shimoda
# Processing Record 1 of Set 6 | hokitika
# Processing Record 2 of Set 6 | hearst
# Processing Record 3 of Set 6 | padang
# Processing Record 4 of Set 6 | menongue
# Processing Record 5 of Set 6 | clyde river
# Processing Record 6 of Set 6 | airai
# Processing Record 7 of Set 6 | yar-sale
# Processing Record 8 of Set 6 | peniche
# Processing Record 9 of Set 6 | borovskoy
# Processing Record 10 of Set 6 | praia da vitoria
# Processing Record 11 of Set 6 | belmonte
# Processing Record 12 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 13 of Set 6 | borogontsy
# Processing Record 14 of Set 6 | broome
# Processing Record 15 of Set 6 | sabang
# Processing Record 16 of Set 6 | ostrovnoy
# Processing Record 17 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 18 of Set 6 | kavieng
# Processing Record 19 of Set 6 | doha
# Processing Record 20 of Set 6 | aksarka
# Processing Record 21 of Set 6 | namatanai
# Processing Record 22 of Set 6 | asyut
# Processing Record 23 of Set 6 | ilulissat
# Processing Record 24 of Set 6 | manokwari
# Processing Record 25 of Set 6 | fairbanks
# Processing Record 26 of Set 6 | lebu
# Processing Record 27 of Set 6 | te anau
# Processing Record 28 of Set 6 | ocampo
# Processing Record 29 of Set 6 | cherskiy
# Processing Record 30 of Set 6 | adolfo lopez mateos
# Processing Record 31 of Set 6 | kerema
# Processing Record 32 of Set 6 | tashigang
# Processing Record 33 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 34 of Set 6 | algiers
# Processing Record 35 of Set 6 | gijon
# Processing Record 36 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 6 | horsham
# Processing Record 38 of Set 6 | strezhevoy
# Processing Record 39 of Set 6 | east london
# Processing Record 40 of Set 6 | general teran
# Processing Record 41 of Set 6 | sorong
# Processing Record 42 of Set 6 | meulaboh
# Processing Record 43 of Set 6 | lompoc
# Processing Record 44 of Set 6 | xining
# Processing Record 45 of Set 6 | cockburn town
# Processing Record 46 of Set 6 | kaitangata
# Processing Record 47 of Set 6 | sao felix do xingu
# Processing Record 48 of Set 6 | sept-iles
# Processing Record 49 of Set 6 | yining
# Processing Record 50 of Set 6 | kubachi
# Processing Record 1 of Set 7 | gafanha da nazare
# Processing Record 2 of Set 7 | sompeta
# Processing Record 3 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 7 | the valley
# Processing Record 5 of Set 7 | natal
# Processing Record 6 of Set 7 | manadhoo
# Processing Record 7 of Set 7 | taguatinga
# Processing Record 8 of Set 7 | praia
# Processing Record 9 of Set 7 | namibe
# Processing Record 10 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 11 of Set 7 | coquimbo
# Processing Record 12 of Set 7 | hasaki
# Processing Record 13 of Set 7 | port keats
# Processing Record 14 of Set 7 | marzuq
# Processing Record 15 of Set 7 | quatre cocos
# Processing Record 16 of Set 7 | havre-saint-pierre
# Processing Record 17 of Set 7 | chakrata
# Processing Record 18 of Set 7 | sioux lookout
# Processing Record 19 of Set 7 | rocha
# Processing Record 20 of Set 7 | kiama
# Processing Record 21 of Set 7 | bandarbeyla
# Processing Record 22 of Set 7 | chumphon
# Processing Record 23 of Set 7 | mananjary
# Processing Record 24 of Set 7 | myitkyina
# Processing Record 25 of Set 7 | bibiani
# Processing Record 26 of Set 7 | verkhnevilyuysk
# Processing Record 27 of Set 7 | byron bay
# Processing Record 28 of Set 7 | gariaband
# Processing Record 29 of Set 7 | fare
# Processing Record 30 of Set 7 | aanekoski
# Processing Record 31 of Set 7 | bredasdorp
# Processing Record 32 of Set 7 | lazaro cardenas
# Processing Record 33 of Set 7 | sitka
# Processing Record 34 of Set 7 | kerchevskiy
# Processing Record 35 of Set 7 | malanje
# Processing Record 36 of Set 7 | soyo
# Processing Record 37 of Set 7 | berlevag
# Processing Record 38 of Set 7 | lubbock
# Processing Record 39 of Set 7 | teya
# Processing Record 40 of Set 7 | dikson
# Processing Record 41 of Set 7 | carauari
# Processing Record 42 of Set 7 | los llanos de aridane
# Processing Record 43 of Set 7 | slavkov u brna
# Processing Record 44 of Set 7 | abbeville
# Processing Record 45 of Set 7 | salinas
# Processing Record 46 of Set 7 | gornyy
# Processing Record 47 of Set 7 | fortuna
# Processing Record 48 of Set 7 | saint andrews
# Processing Record 49 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 7 | cabo san lucas
# Processing Record 1 of Set 8 | novopetrovskoye
# Processing Record 2 of Set 8 | sangar
# Processing Record 3 of Set 8 | lagos
# Processing Record 4 of Set 8 | aguia branca
# Processing Record 5 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 8 | darnah
# Processing Record 7 of Set 8 | olinda
# Processing Record 8 of Set 8 | rajanpur
# Processing Record 9 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 8 | samana
# Processing Record 11 of Set 8 | ust-barguzin
# Processing Record 12 of Set 8 | majene
# Processing Record 13 of Set 8 | big spring
# Processing Record 14 of Set 8 | isangel
# Processing Record 15 of Set 8 | bichura
# Processing Record 16 of Set 8 | corn island
# Processing Record 17 of Set 8 | akyab
# Processing Record 18 of Set 8 | crawfordsville
# Processing Record 19 of Set 8 | tchaourou
# Processing Record 20 of Set 8 | iskateley
# Processing Record 21 of Set 8 | pundaguitan
# Processing Record 22 of Set 8 | helsingborg
# Processing Record 23 of Set 8 | chuy
# Processing Record 24 of Set 8 | leningradskiy
# Processing Record 25 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 26 of Set 8 | nhulunbuy
# Processing Record 27 of Set 8 | gibara
# Processing Record 28 of Set 8 | jasper
# Processing Record 29 of Set 8 | pringsewu
# Processing Record 30 of Set 8 | umm kaddadah
# Processing Record 31 of Set 8 | komsomolskiy
# Processing Record 32 of Set 8 | cap malheureux
# Processing Record 33 of Set 8 | general roca
# Processing Record 34 of Set 8 | deputatskiy
# Processing Record 35 of Set 8 | san antonio
# Processing Record 36 of Set 8 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 37 of Set 8 | muros
# Processing Record 38 of Set 8 | partizanskoye
# Processing Record 39 of Set 8 | karamea
# City not found. Skipping...
# Processing Record 40 of Set 8 | bridlington
# Processing Record 41 of Set 8 | abha
# Processing Record 42 of Set 8 | half moon bay
# Processing Record 43 of Set 8 | carutapera
# Processing Record 44 of Set 8 | longyearbyen
# Processing Record 45 of Set 8 | gidole
# Processing Record 46 of Set 8 | sao filipe
# Processing Record 47 of Set 8 | tatawin
# Processing Record 48 of Set 8 | sao geraldo do araguaia
# Processing Record 49 of Set 8 | vao
# Processing Record 50 of Set 8 | vilyuysk
# Processing Record 1 of Set 9 | batangafo
# Processing Record 2 of Set 9 | chulman
# Processing Record 3 of Set 9 | ahipara
# Processing Record 4 of Set 9 | sechura
# Processing Record 5 of Set 9 | jacareacanga
# Processing Record 6 of Set 9 | miranda
# Processing Record 7 of Set 9 | sagu
# Processing Record 8 of Set 9 | rio gallegos
# Processing Record 9 of Set 9 | adre
# Processing Record 10 of Set 9 | vestmannaeyjar
# Processing Record 11 of Set 9 | tuggurt
# City not found. Skipping...
# Processing Record 12 of Set 9 | bella vista
# Processing Record 13 of Set 9 | ambanja
# Processing Record 14 of Set 9 | lulea
# Processing Record 15 of Set 9 | araouane
# Processing Record 16 of Set 9 | richards bay
# Processing Record 17 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 18 of Set 9 | piacabucu
# Processing Record 19 of Set 9 | kidal
# Processing Record 20 of Set 9 | hermiston
# Processing Record 21 of Set 9 | imbituba
# Processing Record 22 of Set 9 | mogadishu
# Processing Record 23 of Set 9 | pajan
# Processing Record 24 of Set 9 | chandler
# Processing Record 25 of Set 9 | pak thong chai
# Processing Record 26 of Set 9 | poso
# Processing Record 27 of Set 9 | kampot
# Processing Record 28 of Set 9 | digby
# Processing Record 29 of Set 9 | kyra
# Processing Record 30 of Set 9 | bardiyah
# Processing Record 31 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 9 | bassano
# Processing Record 33 of Set 9 | filadelfia
# Processing Record 34 of Set 9 | along
# Processing Record 35 of Set 9 | radebeul
# Processing Record 36 of Set 9 | trinidad
# Processing Record 37 of Set 9 | arkhipo-osipovka
# Processing Record 38 of Set 9 | boddam
# Processing Record 39 of Set 9 | yangambi
# Processing Record 40 of Set 9 | amapa
# Processing Record 41 of Set 9 | uruzgan
# Processing Record 42 of Set 9 | kilindoni
# Processing Record 43 of Set 9 | palauig
# Processing Record 44 of Set 9 | puerto escondido
# Processing Record 45 of Set 9 | takoradi
# Processing Record 46 of Set 9 | saint george
# Processing Record 47 of Set 9 | baherden
# Processing Record 48 of Set 9 | manyana
# Processing Record 49 of Set 9 | umea
# Processing Record 50 of Set 9 | ugoofaaru
# Processing Record 1 of Set 10 | darhan
# Processing Record 2 of Set 10 | benxi
# Processing Record 3 of Set 10 | skara
# Processing Record 4 of Set 10 | shirgaon
# Processing Record 5 of Set 10 | antalaha
# Processing Record 6 of Set 10 | acapulco
# Processing Record 7 of Set 10 | evensk
# Processing Record 8 of Set 10 | najran
# Processing Record 9 of Set 10 | mahebourg
# Processing Record 10 of Set 10 | aden
# Processing Record 11 of Set 10 | korla
# Processing Record 12 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 13 of Set 10 | izumo
# Processing Record 14 of Set 10 | raduzhnyy
# Processing Record 15 of Set 10 | gagra
# Processing Record 16 of Set 10 | kaeo
# Processing Record 17 of Set 10 | kupang
# Processing Record 18 of Set 10 | kampene
# Processing Record 19 of Set 10 | rockland
# Processing Record 20 of Set 10 | vila franca do campo
# Processing Record 21 of Set 10 | madang
# Processing Record 22 of Set 10 | bjorkelangen
# Processing Record 23 of Set 10 | puerto del rosario
# Processing Record 24 of Set 10 | gashua
# Processing Record 25 of Set 10 | yulara
# Processing Record 26 of Set 10 | la baule-escoublac
# Processing Record 27 of Set 10 | barao de cocais
# Processing Record 28 of Set 10 | peachland
# Processing Record 29 of Set 10 | lasa
# Processing Record 30 of Set 10 | narsaq
# Processing Record 31 of Set 10 | belaya gora
# Processing Record 32 of Set 10 | mackay
# Processing Record 33 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 10 | katsuura
# Processing Record 35 of Set 10 | mumbwa
# Processing Record 36 of Set 10 | saint anthony
# Processing Record 37 of Set 10 | guantanamo
# Processing Record 38 of Set 10 | zanjan
# Processing Record 39 of Set 10 | siguiri
# Processing Record 40 of Set 10 | tarija
# Processing Record 41 of Set 10 | mercedes
# Processing Record 42 of Set 10 | huazolotitlan
# City not found. Skipping...
# Processing Record 43 of Set 10 | thilogne
# City not found. Skipping...
# Processing Record 44 of Set 10 | north bend
# Processing Record 45 of Set 10 | haademeeste
# City not found. Skipping...
# Processing Record 46 of Set 10 | kambove
# Processing Record 47 of Set 10 | houma
# Processing Record 48 of Set 10 | vallenar
# Processing Record 49 of Set 10 | kaitong
# Processing Record 50 of Set 10 | mouila
# Processing Record 1 of Set 11 | pacific grove
# Processing Record 2 of Set 11 | changqing
# Processing Record 3 of Set 11 | biskamzha
# Processing Record 4 of Set 11 | hun
# Processing Record 5 of Set 11 | vila velha
# Processing Record 6 of Set 11 | nelson bay
# Processing Record 7 of Set 11 | hoeilaart
# Processing Record 8 of Set 11 | qasigiannguit
# Processing Record 9 of Set 11 | solnechnyy
# Processing Record 10 of Set 11 | nouadhibou
# Processing Record 11 of Set 11 | morro bay
# Processing Record 12 of Set 11 | aurillac
# Processing Record 13 of Set 11 | khandyga
# Processing Record 14 of Set 11 | colares
# Processing Record 15 of Set 11 | ossora
# Processing Record 16 of Set 11 | palma di montechiaro
# Processing Record 17 of Set 11 | puerto narino
# Processing Record 18 of Set 11 | kendari
# Processing Record 19 of Set 11 | canutama
# Processing Record 20 of Set 11 | miramar
# Processing Record 21 of Set 11 | nuevo progreso
# Processing Record 22 of Set 11 | brae
# Processing Record 23 of Set 11 | vardo
# Processing Record 24 of Set 11 | berdigestyakh
# Processing Record 25 of Set 11 | sibay
# Processing Record 26 of Set 11 | faya
# Processing Record 27 of Set 11 | constantine
# Processing Record 28 of Set 11 | port augusta
# Processing Record 29 of Set 11 | coihaique
# Processing Record 30 of Set 11 | saurimo
# Processing Record 31 of Set 11 | tiruchchendur
# Processing Record 32 of Set 11 | port moresby
# Processing Record 33 of Set 11 | bilibino
# Processing Record 34 of Set 11 | paso de carrasco
# Processing Record 35 of Set 11 | magadan
# Processing Record 36 of Set 11 | inta
# Processing Record 37 of Set 11 | tanete
# Processing Record 38 of Set 11 | aksay
# Processing Record 39 of Set 11 | barsovo
# Processing Record 40 of Set 11 | porto novo
# Processing Record 41 of Set 11 | kieta
# Processing Record 42 of Set 11 | sohag
# Processing Record 43 of Set 11 | srednekolymsk
# Processing Record 44 of Set 11 | grenville
# Processing Record 45 of Set 11 | zyryanka
# Processing Record 46 of Set 11 | poum
# Processing Record 47 of Set 11 | mount isa
# Processing Record 48 of Set 11 | balykshi
# Processing Record 49 of Set 11 | santa ana
# Processing Record 50 of Set 11 | yaan
# Processing Record 1 of Set 12 | djambala
# Processing Record 2 of Set 12 | dayong
# Processing Record 3 of Set 12 | sinegorskiy
# Processing Record 4 of Set 12 | donskoye
# Processing Record 5 of Set 12 | tazovskiy
# Processing Record 6 of Set 12 | russell
# Processing Record 7 of Set 12 | lloret de mar
# Processing Record 8 of Set 12 | soure
# Processing Record 9 of Set 12 | krasnoselkup
# Processing Record 10 of Set 12 | santa maria
# Processing Record 11 of Set 12 | bobbili
# Processing Record 12 of Set 12 | iracoubo
# Processing Record 13 of Set 12 | broken hill
# Processing Record 14 of Set 12 | miraflores
# Processing Record 15 of Set 12 | port hardy
# Processing Record 16 of Set 12 | yarensk
# Processing Record 17 of Set 12 | arlit
# Processing Record 18 of Set 12 | upington
# Processing Record 19 of Set 12 | port blair
# Processing Record 20 of Set 12 | san angelo
# Processing Record 21 of Set 12 | wajir
# Processing Record 22 of Set 12 | arica
# Processing Record 23 of Set 12 | chadiza
# Processing Record 24 of Set 12 | marawi
# Processing Record 25 of Set 12 | arari
# Processing Record 26 of Set 12 | port-gentil
# Processing Record 27 of Set 12 | san rafael del sur
# Processing Record 28 of Set 12 | buchanan
# Processing Record 29 of Set 12 | goderich
# Processing Record 30 of Set 12 | zambezi
# Processing Record 31 of Set 12 | champerico
# Processing Record 32 of Set 12 | kesova gora
# Processing Record 33 of Set 12 | gombe
# Processing Record 34 of Set 12 | nalbari
# Processing Record 35 of Set 12 | ardakan
# Processing Record 36 of Set 12 | longview
# Processing Record 37 of Set 12 | tocopilla
# Processing Record 38 of Set 12 | agirish
# Processing Record 39 of Set 12 | shelburne
# Processing Record 40 of Set 12 | kontagora
# Processing Record 41 of Set 12 | gillette
# Processing Record 42 of Set 12 | kamiiso
# Processing Record 43 of Set 12 | cozumel
# Processing Record 44 of Set 12 | astoria
# Processing Record 45 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 46 of Set 12 | jaisalmer
# Processing Record 47 of Set 12 | gazni
# City not found. Skipping...
# Processing Record 48 of Set 12 | faranah
# Processing Record 49 of Set 12 | zaranj
# Processing Record 50 of Set 12 | anadyr
# Processing Record 1 of Set 13 | ambilobe
# Processing Record 2 of Set 13 | noyabrsk
# Processing Record 3 of Set 13 | siena
# Processing Record 4 of Set 13 | nalut
# Processing Record 5 of Set 13 | shubarkuduk
# Processing Record 6 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 7 of Set 13 | suez
# Processing Record 8 of Set 13 | urengoy
# Processing Record 9 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 13 | atyrau
# Processing Record 11 of Set 13 | changping
# Processing Record 12 of Set 13 | sur
# Processing Record 13 of Set 13 | tiarei
# Processing Record 14 of Set 13 | grindavik
# Processing Record 15 of Set 13 | atasu
# Processing Record 16 of Set 13 | mackenzie
# Processing Record 17 of Set 13 | tarko-sale
# Processing Record 18 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 19 of Set 13 | garanhuns
# Processing Record 20 of Set 13 | shenjiamen
# Processing Record 21 of Set 13 | santo domingo
# Processing Record 22 of Set 13 | sao joao da barra
# Processing Record 23 of Set 13 | dalbandin
# Processing Record 24 of Set 13 | karamay
# City not found. Skipping...
# Processing Record 25 of Set 13 | kalghatgi
# Processing Record 26 of Set 13 | hamilton
# Processing Record 27 of Set 13 | santa cruz
# Processing Record 28 of Set 13 | sovetskiy
# Processing Record 29 of Set 13 | likasi
# Processing Record 30 of Set 13 | marabba
# Processing Record 31 of Set 13 | maniwaki
# Processing Record 32 of Set 13 | kjollefjord
# Processing Record 33 of Set 13 | fort morgan
# Processing Record 34 of Set 13 | sorland
# Processing Record 35 of Set 13 | rosarito
# Processing Record 36 of Set 13 | cangucu
# Processing Record 37 of Set 13 | casa grande
# Processing Record 38 of Set 13 | preston
# Processing Record 39 of Set 13 | ewa beach
# Processing Record 40 of Set 13 | longkou
# Processing Record 41 of Set 13 | arenapolis
# Processing Record 42 of Set 13 | araxa
# Processing Record 43 of Set 13 | manavalakurichi
# Processing Record 44 of Set 13 | conroe
# Processing Record 45 of Set 13 | vila
# Processing Record 46 of Set 13 | tsumeb
# Processing Record 47 of Set 13 | pisco
# Processing Record 48 of Set 13 | dudinka
# Processing Record 49 of Set 13 | ostersund
# Processing Record 50 of Set 13 | tigre
# Processing Record 1 of Set 14 | pesnica pri mariboru
# Processing Record 2 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 14 | baruun-urt
# Processing Record 4 of Set 14 | kadykchan
# City not found. Skipping...
# Processing Record 5 of Set 14 | bud
# Processing Record 6 of Set 14 | yantal
# Processing Record 7 of Set 14 | tari
# Processing Record 8 of Set 14 | shumskiy
# Processing Record 9 of Set 14 | yarmouth
# Processing Record 10 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 11 of Set 14 | sawakin
# Processing Record 12 of Set 14 | siverek
# Processing Record 13 of Set 14 | ocos
# Processing Record 14 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 15 of Set 14 | tiznit
# Processing Record 16 of Set 14 | vestbygda
# City not found. Skipping...
# Processing Record 17 of Set 14 | ixtapa
# Processing Record 18 of Set 14 | honningsvag
# Processing Record 19 of Set 14 | cleveland
# Processing Record 20 of Set 14 | solano
# Processing Record 21 of Set 14 | young
# Processing Record 22 of Set 14 | monrovia
# Processing Record 23 of Set 14 | tecpan
# Processing Record 24 of Set 14 | elizabethtown
# Processing Record 25 of Set 14 | mayya
# Processing Record 26 of Set 14 | tukrah
# Processing Record 27 of Set 14 | juazeiro
# Processing Record 28 of Set 14 | khanpur
# Processing Record 29 of Set 14 | jamiltepec
# Processing Record 30 of Set 14 | fort nelson
# Processing Record 31 of Set 14 | sayanogorsk
# Processing Record 32 of Set 14 | lagoa
# Processing Record 33 of Set 14 | harnosand
# Processing Record 34 of Set 14 | itarema
# Processing Record 35 of Set 14 | contamana
# Processing Record 36 of Set 14 | port macquarie
# Processing Record 37 of Set 14 | santo antonio do ica
# Processing Record 38 of Set 14 | lampazos de naranjo
# Processing Record 39 of Set 14 | shahr-e babak
# Processing Record 40 of Set 14 | saint-pierre
# Processing Record 41 of Set 14 | bitam
# Processing Record 42 of Set 14 | pontes e lacerda
# Processing Record 43 of Set 14 | cavalcante
# Processing Record 44 of Set 14 | beringovskiy
# Processing Record 45 of Set 14 | tizapan el alto
# Processing Record 46 of Set 14 | trairi
# Processing Record 47 of Set 14 | mayor pablo lagerenza
# Processing Record 48 of Set 14 | bordighera
# Processing Record 49 of Set 14 | la ronge
# Processing Record 50 of Set 14 | kirando
# Processing Record 1 of Set 15 | inhambane
# Processing Record 2 of Set 15 | jutai
# Processing Record 3 of Set 15 | rawah
# Processing Record 4 of Set 15 | shushtar
# Processing Record 5 of Set 15 | south yuba city
# Processing Record 6 of Set 15 | sinnamary
# Processing Record 7 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 8 of Set 15 | qaqortoq
# Processing Record 9 of Set 15 | abilene
# Processing Record 10 of Set 15 | ginda
# Processing Record 11 of Set 15 | bayir
# Processing Record 12 of Set 15 | wethersfield
# Processing Record 13 of Set 15 | babol
# Processing Record 14 of Set 15 | fort saint john
# City not found. Skipping...
# Processing Record 15 of Set 15 | cabral
# Processing Record 16 of Set 15 | campos belos
# Processing Record 17 of Set 15 | mahibadhoo
# Processing Record 18 of Set 15 | itaueira
# Processing Record 19 of Set 15 | vimperk
# Processing Record 20 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 15 | bathsheba
# Processing Record 22 of Set 15 | marathon
# Processing Record 23 of Set 15 | halifax
# Processing Record 24 of Set 15 | buraydah
# Processing Record 25 of Set 15 | lucapa
# Processing Record 26 of Set 15 | pangkalanbuun
# Processing Record 27 of Set 15 | forrest city
# Processing Record 28 of Set 15 | taitung
# Processing Record 29 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 30 of Set 15 | tevaitoa
# Processing Record 31 of Set 15 | almenara
# Processing Record 32 of Set 15 | pangody
# Processing Record 33 of Set 15 | slave lake
# Processing Record 34 of Set 15 | atar
# Processing Record 35 of Set 15 | kokopo
# Processing Record 36 of Set 15 | hualmay
# Processing Record 37 of Set 15 | dabola
# Processing Record 38 of Set 15 | kawalu
# Processing Record 39 of Set 15 | yuanping
# Processing Record 40 of Set 15 | tanout
# Processing Record 41 of Set 15 | soria
# Processing Record 42 of Set 15 | oussouye
# Processing Record 43 of Set 15 | siderno
# Processing Record 44 of Set 15 | linhares
# Processing Record 45 of Set 15 | bonthe
# Processing Record 46 of Set 15 | calvinia
# Processing Record 47 of Set 15 | ajdabiya
# Processing Record 48 of Set 15 | west bay
# Processing Record 49 of Set 15 | okhotsk
# Processing Record 50 of Set 15 | batemans bay
# Processing Record 1 of Set 16 | altus
# Processing Record 2 of Set 16 | yushu
# Processing Record 3 of Set 16 | srandakan
# Processing Record 4 of Set 16 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 16 | keelung
# Processing Record 6 of Set 16 | wilmington
# Processing Record 7 of Set 16 | liverpool
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries into a DF

city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Rikitea      PF -23.1203 -134.9692     77.97        72          97
# 1   Ciudad Guayana      VE   8.3533  -62.6528     83.52        67          41
# 2     Punta Arenas      CL -53.1500  -70.9167     51.91        43           0
# 3          Qaanaaq      GL  77.4840  -69.3632     -7.37        61          96
# 4            Kapaa      US  22.0752 -159.3190     66.18        88           0
# 5        Cape Town      ZA -33.9258   18.4232     73.81        49           0
# 6          Serenje      ZM -13.2325   30.2352     61.12        98         100
# 7        Busselton      AU -33.6500  115.3333     74.08        73           0
# 8      Provideniya      RU  64.3833 -173.3000     -0.42        65           7
# 9  Bambous Virieux      MU -20.3428   57.7575     80.22        94          75
#
#    Wind Speed Current Description
# 0       11.07          light rain
# 1        7.00    scattered clouds
# 2       10.36           clear sky
# 3        8.88     overcast clouds
# 4        6.91           clear sky
# 5        8.01           clear sky
# 6        7.63     overcast clouds
# 7        6.46           clear sky
# 8       15.08           clear sky
# 9       17.27          light rain

# %%
city_data_df.count()
# Out:
# City                   706
# Country                706
# Lat                    706
# Lng                    706
# Max Temp               706
# Humidity               706
# Cloudiness             706
# Wind Speed             706
# Current Description    706
# dtype: int64

# %%
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %%
# Create the output file (CSV)

output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV, the index_label is the header for column A in the CSV

city_data_df.to_csv(output_data_file, index_label="City_ID")
